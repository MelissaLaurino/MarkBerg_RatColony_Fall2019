# %% [markdown]
# Melissa Laurino<br>
# Stockton University - Animal Lab <br>
# <b>Mark Berg Rat Colony</b><br>
# September 24, 2019 - Present

# %%
print ('Last updated:')
import datetime
date = datetime.datetime.now()
print (date)
# Out:
# Last updated:
# 2019-11-04 10:35:51.927968

# %% [markdown]
# <b> Getting Started: Import libraries and data

# %%
#Import necessary libraries:
import pandas as pd #Data import
import numpy as np #Math functions
import matplotlib.pyplot as plt #Graphing library

#Import data using Pandas:
rats = pd.read_excel('MarkBergRatColony_2019.xlsx')

#Take a subset of the data to not include the excel formula rows
rats = rats[(rats.Date >= '2019-09-24') & (rats.Date < '2019-12-31')]
     
#rats.loc['2019-09-24':'2019-12-31']

print(rats)
# Out:
#           Date  RATID  Weight_g     Sex  Cage             Acronym  \
# 10  2019-09-24      1     434.0    Male     1              1/3WTT
# 11  2019-09-24      2     418.0    Male     1  1/2WTT/1BSU/1BSRRL
# 12  2019-09-24      3     409.0    Male     1         1/2WTT/2BSU
# 13  2019-09-24      4     383.0    Male     1         3/4WTT/3BSU
# 14  2019-09-24      5     443.0    Male     2         1/4WTT/2BSU
# 15  2019-09-24      6     401.0    Male     2         1/4WTT/1BSU
# 16  2019-09-24      7     473.0    Male     2      1/2WTT/1BS/RRL
# 17  2019-09-24      8     282.0  Female     3              1/4WTT
# 18  2019-09-24      9     256.0  Female     3          1/2WTT/2SL
# 19  2019-09-24     10     265.0  Female     3      1/2WTT/1SL/1SR
# 20  2019-09-25      1     446.0    Male     1              1/3WTT
# 21  2019-09-25      2     429.0    Male     1  1/2WTT/1BSU/1BSRRL
# 22  2019-09-25      3     417.0    Male     1         1/2WTT/2BSU
# 23  2019-09-25      4     392.0    Male     1         3/4WTT/3BSU
# 24  2019-09-25      5     452.0    Male     2         1/4WTT/2BSU
# 25  2019-09-25      6     412.0    Male     2         1/4WTT/1BSU
# 26  2019-09-25      7     482.0    Male     2      1/2WTT/1BS/RRL
# 27  2019-09-25      8     284.0  Female     3              1/4WTT
# 28  2019-09-25      9     256.0  Female     3          1/2WTT/2SL
# 29  2019-09-25     10     271.0  Female     3      1/2WTT/1SL/1SR
# 30  2019-09-26      1     450.0    Male     1              1/3WTT
# 31  2019-09-26      2     424.0    Male     1  1/2WTT/1BSU/1BSRRL
# 32  2019-09-26      3     419.0    Male     1         1/2WTT/2BSU
# 33  2019-09-26      4     391.0    Male     1         3/4WTT/3BSU
# 34  2019-09-26      5     459.0    Male     2         1/4WTT/2BSU
# 35  2019-09-26      6     414.0    Male     2         1/4WTT/1BSU
# 36  2019-09-26      7     483.0    Male     2      1/2WTT/1BS/RRL
# 37  2019-09-26      8     304.0  Female     3              1/4WTT
# 38  2019-09-26      9     258.0  Female     3          1/2WTT/2SL
# 39  2019-09-26     10     274.0  Female     3      1/2WTT/1SL/1SR
# ..         ...    ...       ...     ...   ...                 ...
# 960 2019-12-28      1       NaN    Male     1              1/3WTT
# 961 2019-12-28      2       NaN    Male     1  1/2WTT/1BSU/1BSRRL
# 962 2019-12-28      3       NaN    Male     1         1/2WTT/2BSU
# 963 2019-12-28      4       NaN    Male     1         3/4WTT/3BSU
# 964 2019-12-28      5       NaN    Male     2         1/4WTT/2BSU
# 965 2019-12-28      6       NaN    Male     2         1/4WTT/1BSU
# 966 2019-12-28      7       NaN    Male     2      1/2WTT/1BS/RRL
# 967 2019-12-28      8       NaN  Female     3              1/4WTT
# 968 2019-12-28      9       NaN  Female     3          1/2WTT/2SL
# 969 2019-12-28     10       NaN  Female     3      1/2WTT/1SL/1SR
# 970 2019-12-29      1       NaN    Male     1              1/3WTT
# 971 2019-12-29      2       NaN    Male     1  1/2WTT/1BSU/1BSRRL
# 972 2019-12-29      3       NaN    Male     1         1/2WTT/2BSU
# 973 2019-12-29      4       NaN    Male     1         3/4WTT/3BSU
# 974 2019-12-29      5       NaN    Male     2         1/4WTT/2BSU
# 975 2019-12-29      6       NaN    Male     2         1/4WTT/1BSU
# 976 2019-12-29      7       NaN    Male     2      1/2WTT/1BS/RRL
# 977 2019-12-29      8       NaN  Female     3              1/4WTT
# 978 2019-12-29      9       NaN  Female     3          1/2WTT/2SL
# 979 2019-12-29     10       NaN  Female     3      1/2WTT/1SL/1SR
# 980 2019-12-30      1       NaN    Male     1              1/3WTT
# 981 2019-12-30      2       NaN    Male     1  1/2WTT/1BSU/1BSRRL
# 982 2019-12-30      3       NaN    Male     1         1/2WTT/2BSU
# 983 2019-12-30      4       NaN    Male     1         3/4WTT/3BSU
# 984 2019-12-30      5       NaN    Male     2         1/4WTT/2BSU
# 985 2019-12-30      6       NaN    Male     2         1/4WTT/1BSU
# 986 2019-12-30      7       NaN    Male     2      1/2WTT/1BS/RRL
# 987 2019-12-30      8       NaN  Female     3              1/4WTT
# 988 2019-12-30      9       NaN  Female     3          1/2WTT/2SL
# 989 2019-12-30     10       NaN  Female     3      1/2WTT/1SL/1SR
#
#                                    Rat Characteristics  \
# 10                               1/3 White tipped tail
# 11   1/2 White tipped tail/1 Black Spot Underside/1...
# 12       1/2 White tipped tail/2 Black Spots Underside
# 13      3/4 White tipped tail/ 3 Black Spots Underside
# 14      1/4 White tippled tail/2 Black spots underside
# 15      1/4 White tippled tail/1 Black spots underside
# 16   1/2 White tipped tail/1 Black Spot/Right rear leg
# 17                               1/4 White tipped tail
# 18                  1/2 White tipped tail/2 Spots Left
# 19      1/2 White tipped tail/1 Spot Left/1 Spot Right
# 20                               1/3 White tipped tail
# 21   1/2 White tipped tail/1 Black Spot Underside/1...
# 22       1/2 White tipped tail/2 Black Spots Underside
# 23      3/4 White tipped tail/ 3 Black Spots Underside
# 24      1/4 White tippled tail/2 Black spots underside
# 25      1/4 White tippled tail/1 Black spots underside
# 26   1/2 White tipped tail/1 Black Spot/Right rear leg
# 27                               1/4 White tipped tail
# 28                  1/2 White tipped tail/2 Spots Left
# 29      1/2 White tipped tail/1 Spot Left/1 Spot Right
# 30                               1/3 White tipped tail
# 31   1/2 White tipped tail/1 Black Spot Underside/1...
# 32       1/2 White tipped tail/2 Black Spots Underside
# 33      3/4 White tipped tail/ 3 Black Spots Underside
# 34      1/4 White tippled tail/2 Black spots underside
# 35      1/4 White tippled tail/1 Black spots underside
# 36   1/2 White tipped tail/1 Black Spot/Right rear leg
# 37                               1/4 White tipped tail
# 38                  1/2 White tipped tail/2 Spots Left
# 39      1/2 White tipped tail/1 Spot Left/1 Spot Right
# ..                                                 ...
# 960                              1/3 White tipped tail
# 961  1/2 White tipped tail/1 Black Spot Underside/1...
# 962      1/2 White tipped tail/2 Black Spots Underside
# 963     3/4 White tipped tail/ 3 Black Spots Underside
# 964     1/4 White tippled tail/2 Black spots underside
# 965     1/4 White tippled tail/1 Black spots underside
# 966  1/2 White tipped tail/1 Black Spot/Right rear leg
# 967                              1/4 White tipped tail
# 968                 1/2 White tipped tail/2 Spots Left
# 969     1/2 White tipped tail/1 Spot Left/1 Spot Right
# 970                              1/3 White tipped tail
# 971  1/2 White tipped tail/1 Black Spot Underside/1...
# 972      1/2 White tipped tail/2 Black Spots Underside
# 973     3/4 White tipped tail/ 3 Black Spots Underside
# 974     1/4 White tippled tail/2 Black spots underside
# 975     1/4 White tippled tail/1 Black spots underside
# 976  1/2 White tipped tail/1 Black Spot/Right rear leg
# 977                              1/4 White tipped tail
# 978                 1/2 White tipped tail/2 Spots Left
# 979     1/2 White tipped tail/1 Spot Left/1 Spot Right
# 980                              1/3 White tipped tail
# 981  1/2 White tipped tail/1 Black Spot Underside/1...
# 982      1/2 White tipped tail/2 Black Spots Underside
# 983     3/4 White tipped tail/ 3 Black Spots Underside
# 984     1/4 White tippled tail/2 Black spots underside
# 985     1/4 White tippled tail/1 Black spots underside
# 986  1/2 White tipped tail/1 Black Spot/Right rear leg
# 987                              1/4 White tipped tail
# 988                 1/2 White tipped tail/2 Spots Left
# 989     1/2 White tipped tail/1 Spot Left/1 Spot Right
#
#      Deprivation Started: 10/16/19
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32                             NaN
# 33                             NaN
# 34                             NaN
# 35                             NaN
# 36                             NaN
# 37                             NaN
# 38                             NaN
# 39                             NaN
# ..                             ...
# 960                            NaN
# 961                            NaN
# 962                            NaN
# 963                            NaN
# 964                            NaN
# 965                            NaN
# 966                            NaN
# 967                            NaN
# 968                            NaN
# 969                            NaN
# 970                            NaN
# 971                            NaN
# 972                            NaN
# 973                            NaN
# 974                            NaN
# 975                            NaN
# 976                            NaN
# 977                            NaN
# 978                            NaN
# 979                            NaN
# 980                            NaN
# 981                            NaN
# 982                            NaN
# 983                            NaN
# 984                            NaN
# 985                            NaN
# 986                            NaN
# 987                            NaN
# 988                            NaN
# 989                            NaN
#
# [980 rows x 8 columns]

# %% [markdown]
# <b>How many times was each rat weighed?

# %%
Rat_ID = rats.groupby('RATID')
Rat_ID_totals = Rat_ID.size()
#print (Rat_ID_totals.head())
m = Rat_ID_totals.plot(kind='bar')
m.set_xlabel("Rat ID")
m.set_ylabel("Number of times weighed")
m.set_title("Mark Berg - Animal Lab")
m
print ('Each rat weighed:')
print (Rat_ID_totals.head())
print ()
print ('Each rat was weighed X times during September 24, 2019 - Present.')
# Out:
# Each rat weighed:
# RATID
# 1    98
# 2    98
# 3    98
# 4    98
# 5    98
# dtype: int64
#
# Each rat was weighed X times during September 24, 2019 - Present.

# %% [markdown]
# <b>What was the range of each rat's weight?

# %%
plt.figure(figsize=(20,8))
plt.plot(rats.RATID, rats.Weight_g,'.')
plt.xlabel('Rat ID', fontsize=20)
plt.ylabel('Weight (g)', fontsize=20)
plt.legend()
plt.title('Mark Berg Rat Colony', fontsize=24)
#plt.savefig('C://Users//Dhairya//Desktop//MeasureDepthAmericanStar2016.png')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# <b>Document rat weight by ID over time:

# %%
Rat1 = rats[rats.RATID == 1]
Rat2 = rats[rats.RATID == 2]
Rat3 = rats[rats.RATID == 3]
Rat4 = rats[rats.RATID == 4]
Rat5 = rats[rats.RATID == 5]
Rat6 = rats[rats.RATID == 6]
Rat7 = rats[rats.RATID == 7]
Rat8 = rats[rats.RATID == 8]
Rat9 = rats[rats.RATID == 9]
Rat10 = rats[rats.RATID == 10]

dfRat1 = rats[['RATID', 'Weight_g']]

# %%
from matplotlib import colors as mcolors #Color features

plt.figure(figsize=(25,12))
plt.plot(Rat1.Date, Rat1.Weight_g, "b-", label='Rat 1 - 1/3WTT',linewidth= 2,markersize=5, alpha=.90)
plt.plot(Rat2.Date, Rat2.Weight_g, "c-", label='Rat 2 - 1/2WTT/1BSU/1BSRRL',linewidth= 2,markersize=5, alpha=.50)
plt.plot(Rat3.Date, Rat3.Weight_g, "g-", label='Rat 3 - 1/2WTT/2BSU',linewidth= 2,markersize=5, alpha=.50)
plt.plot(Rat4.Date, Rat4.Weight_g, "r-", label='Rat 4 - 3/4WTT/3BSU',linewidth= 2,markersize=5, alpha=.70)
plt.plot(Rat5.Date, Rat5.Weight_g, "m-", label='Rat 5 - 1/4WTT/2BSU',linewidth= 2,markersize=5, alpha=.90)
plt.plot(Rat6.Date, Rat6.Weight_g, "r-", label='Rat 6 - 1/4WTT/1BSU',linewidth= 2,markersize=5, alpha=.30)
plt.plot(Rat7.Date, Rat7.Weight_g, "k-", label='Rat 7 - 1/2WTT/1BS/RRL',linewidth= 2,markersize=5, alpha=.40)
plt.plot(Rat8.Date, Rat8.Weight_g, "y-", label='Rat 8 - 1/4WTT',linewidth= 2,markersize=5, alpha=.90)
plt.plot(Rat9.Date, Rat9.Weight_g, "y-", label='Rat 9 - 1/2WTT/2SL',linewidth= 2,markersize=5, alpha=.50)
plt.plot(Rat10.Date, Rat10.Weight_g, "y-", label='Rat 10 - 1/2WTT/1SL/1SR',linewidth= 2,markersize=5, alpha=.30)

#plt.plot(rats.Weight_g, rats.RATID, "r", label='XXX',linewidth= 2.5, markersize=5, alpha=.50)

plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Mark Berg Rat Colony - Fall 2019', fontsize=18)
#plt.savefig('C://Users//Dhairya//Desktop//MeasuredWindSpeedAmericanStar2016.png')
plt.show()
print("Deprivation started: 10/16/19")
print("Deprivation increased: XX")
# Out:
# Deprivation started: 10/16/19
# Deprivation increased: XX

# %% [markdown]
# <b>Take a closer look at each rat individually by ID and enclosure set up:

# %%
#print(Rat1)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat1.Date, Rat1.Weight_g, "b-", label='Male Rat 1 - 1/3WTT',linewidth= 4,markersize=5, alpha=.90)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 1 - 1/3WTT', fontsize=16)
plt.show()

# %%
#print(Rat2)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat2.Date, Rat2.Weight_g, "c-", label='Rat 2 - 1/2WTT/1BSU/1BSRRL',linewidth= 4,markersize=5, alpha=.80)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 2 - 1/2WTT/1BSU/1BSRRL', fontsize=16)
plt.show()

# %%
#print(Rat3)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat3.Date, Rat3.Weight_g, "g-", label='Rat 3 - 1/2WTT/2BSU',linewidth= 4,markersize=5, alpha=.50)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 3 - 1/2WTT/2BSU', fontsize=16)
plt.show()

# %%
#print(Rat4)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat4.Date, Rat4.Weight_g, "r-", label='Rat 4 - 1/2WT/BSU',linewidth= 4,markersize=5, alpha=.70)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 4 - 1/2WT/BSU', fontsize=16)
plt.show()

# %%
#Plot all of the rats in Cage #1:
plt.figure(figsize=(20,8))
plt.plot(Rat1.Date, Rat1.Weight_g, "b-", label='Rat 1 - 1/3WTT',linewidth= 2,markersize=5, alpha=.90)
plt.plot(Rat2.Date, Rat2.Weight_g, "c-", label='Rat 2 - 1/2WTT/1BSU/1BSRRL',linewidth= 2,markersize=5, alpha=.50)
plt.plot(Rat3.Date, Rat3.Weight_g, "g-", label='Rat 3 - 1/2WTT/2BSU',linewidth= 2,markersize=5, alpha=.50)
plt.plot(Rat4.Date, Rat4.Weight_g, "r-", label='Rat 4 - 3/4WTT/3BSU',linewidth= 4,markersize=5, alpha=.70)

plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Cage #1 - Rat ID 1, 2, 3 and 4', fontsize=18)
plt.show()

# %%
#Plot all of the rats in Cage #1 A:
plt.figure(figsize=(20,8))
plt.plot(Rat1.Date, Rat1.Weight_g, "b-", label='Rat 1 - 1/3WTT',linewidth= 2,markersize=5, alpha=.90)
plt.plot(Rat2.Date, Rat2.Weight_g, "c-", label='Rat 2 - 1/2WTT/1BSU/1BSRRL',linewidth= 2,markersize=5, alpha=.50)

plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Cage #1 - Rat ID 1, and 2', fontsize=18)
plt.show()

# %%
#Plot all of the rats in Cage #1 B:
plt.figure(figsize=(20,8))
plt.plot(Rat3.Date, Rat3.Weight_g, "g-", label='Rat 3 - 1/2WTT/2BSU',linewidth= 2,markersize=5, alpha=.50)
plt.plot(Rat4.Date, Rat4.Weight_g, "r-", label='Rat 4 - 3/4WTT/3BSU',linewidth= 4,markersize=5, alpha=.70)

plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Cage #1 - Rat ID 3 and 4', fontsize=18)
plt.show()

# %%
#print(Rat5)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat5.Date, Rat5.Weight_g, "m-", label='Rat 5 - 1/4WTT/2BSU',linewidth= 2,markersize=5, alpha=.90)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 5 - 1/4WTT/2BSU', fontsize=16)
plt.show()

# %%
#print(Rat6)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat6.Date, Rat6.Weight_g, "r-", label='1/4WTT/1BSU',linewidth= 2,markersize=5, alpha=.30)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 6 - 1/4WTT/1BSU', fontsize=16)
plt.show()

# %%
#print(Rat7)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat7.Date, Rat7.Weight_g, "m-", label='Rat 7 - 1/2WTT/1BS/RRL',linewidth= 2,markersize=5, alpha=.40)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 7 - 1/2WTT/1BS/RRL', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,8))

plt.plot(Rat5.Date, Rat5.Weight_g, "r-", label='Rat 5 - 1/4WTT/2BSU',linewidth= 2,markersize=5, alpha=.70)
plt.plot(Rat6.Date, Rat6.Weight_g, "m-", label='Rat 6 - 1/4WTT/1BSU',linewidth= 2,markersize=5, alpha=.90)
plt.plot(Rat7.Date, Rat7.Weight_g, "r-", label='Rat 7 - 1/2WTT/1BS/RRL',linewidth= 2,markersize=5, alpha=.30)

plt.ylabel('Weight (g)',  fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Cage #2 - Rat ID 5, 6 and 7',  fontsize=18)
plt.show()

# %%
#print(Rat8)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat8.Date, Rat8.Weight_g, "y-", label='Rat 8 - 1/4WTT',linewidth= 2,markersize=5, alpha=.90)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 8 - 1/4WTT', fontsize=16)
plt.show()

# %%
#print(Rat9)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat9.Date, Rat9.Weight_g, "y-", label='Rat 9 - 1/2WTT/2SL',linewidth= 2,markersize=5, alpha=.50)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 9 - 1/2WTT/2SL', fontsize=16)
plt.show()

# %%
#print(Rat10)

# %%
plt.figure(figsize=(20,8))
plt.plot(Rat10.Date, Rat10.Weight_g, "y-", label='Rat 10 - 1/2WTT/1SL/1SR',linewidth= 2,markersize=5, alpha=.30)
plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Rat 10 - 1/2WTT/1SL/1SR', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,8))

plt.plot(Rat8.Date, Rat8.Weight_g, "y-", label='Rat 8 - 1/4WTT',linewidth= 2,markersize=5, alpha=.90)
plt.plot(Rat9.Date, Rat9.Weight_g, "y-", label='Rat 9 - 1/2WTT/2SL',linewidth= 2,markersize=5, alpha=.50)
plt.plot(Rat10.Date, Rat10.Weight_g, "y-", label='Rat 10 - 1/2WTT/1SL/1SR',linewidth= 2,markersize=5, alpha=.30)

plt.ylabel('Weight (g)', fontsize=16)
plt.xlabel('Date', fontsize=16)
plt.legend()
plt.title('Females - Cage #3 - Rat ID 8, 9 and 10', fontsize=18)
plt.show()
